# %% [markdown]
# # Downloading Images

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import json

def generate_download_list(annotation_file, output_file):
    """Generate a list of image URLs for download"""

    with open(annotation_file, 'r') as f:
        annotations = json.load(f)

    dataset_type = 'train2017' if 'train' in annotation_file else 'val2017'

    with open(output_file, 'w') as f:
        for img_info in annotations['images']:
            url = f"http://images.cocodataset.org/{dataset_type}/{img_info['file_name']}\n"
            f.write(url)

#Generate download lists
generate_download_list('/content/drive/MyDrive/DATASET/filtered_train2017.json', 'train_images.txt')
generate_download_list('/content/drive/MyDrive/DATASET/filtered_val2017.json', 'val_images.txt')

print("Download lists generated. Use:")
print("wget -i train_images.txt -P filtered_train2017/")
print("wget -i val_images.txt -P filtered_val2017/")
# Out:
# Download lists generated. Use:
# wget -i train_images.txt -P filtered_train2017/
# wget -i val_images.txt -P filtered_val2017/

# %%
with open('train_images.txt', 'r') as f:
  links = f.readlines()
  cntr=0
  for link in links:
    if link != ' ' or link != '\n':
      cntr+=1
  print(f'Number of images : {cntr}')
# Out:
# Number of images : 32801

# %%
with open('val_images.txt', 'r') as f:
  links = f.readlines()
  cntr=0
  for link in links:
    if link != ' ' or link != '\n':
      cntr+=1
  print(f'Number of images : {cntr}')
# Out:
# Number of images : 4082

# %%
#!wget -i val_images.txt -P /content/drive/MyDrive/COCO2017Val

# %%
#!wget -i train_images.txt -P /content/drive/MyDrive/COCODataset2017/COCO2017train

# %% [markdown]
# #Downloading labels

# %%
#paths
trainjson_path = '/content/drive/MyDrive/DATASET/filtered_train2017.json'
valjson_path = '/content/drive/MyDrive/DATASET/filtered_val2017.json'

# %%
with open (trainjson_path, 'r') as trainjson_path:
  data = json.load(trainjson_path)

# %%
imgs = data['images']
imgs
# Out:
# [{'license': 3,
#   'file_name': '000000574769.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000574769.jpg',
#   'height': 640,
#   'width': 480,
#   'date_captured': '2013-11-14 17:07:59',
#   'flickr_url': 'http://farm8.staticflickr.com/7010/6728227647_3d5a0d55ee_z.jpg',
#   'id': 574769},
#  {'license': 4,
#   'file_name': '000000060623.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000060623.jpg',
#   'height': 427,
#   'width': 640,
#   'date_captured': '2013-11-14 17:24:15',
#   'flickr_url': 'http://farm7.staticflickr.com/6080/6113512699_37b4c98473_z.jpg',
#   'id': 60623},
#  {'license': 2,
#   'file_name': '000000005802.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000005802.jpg',
#   'height': 479,
#   'width': 640,
#   'date_captured': '2013-11-14 17:28:25',
#   'flickr_url': 'http://farm4.staticflickr.com/3810/9614287841_1b724dbbc5_z.jpg',
#   'id': 5802},
#  {'license': 2,
#   'file_name': '000000374628.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000374628.jpg',
#   'height': 326,
#   'width': 640,
#   'date_captured': '2013-11-14 19:18:11',
#   'flickr_url': 'http://farm5.staticflickr.com/4070/4444442937_5aba7a1c31_z.jpg',
#   'id': 374628},
#  {'license': 3,
#   'file_name': '000000328757.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000328757.jpg',
#   'height': 332,
#   'width': 500,
#   'date_captured': '2013-11-14 19:34:34',
#   'flickr_url': 'http://farm4.staticflickr.com/3079/2532983426_373865b789_z.jpg',
#   'id': 328757},
#  {'license': 3,
#   'file_name': '000000386164.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000386164.jpg',
#   'height': 640,
#   'width': 480,
#   'date_captured': '2013-11-14 21:06:13',
#   'flickr_url': 'http://farm6.staticflickr.com/5216/5384496530_f0aa6628a2_z.jpg',
#   'id': 386164},
#  {'license': 3,
#   'file_name': '000000223648.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000223648.jpg',
#   'height': 640,
#   'width': 480,
#   'date_captured': '2013-11-14 21:06:15',
#   'flickr_url': 'http://farm6.staticflickr.com/5219/5383892439_6ef5ba6f23_z.jpg',
#   'id': 223648},
#  {'license': 2,
#   'file_name': '000000337264.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000337264.jpg',
#   'height': 427,
#   'width': 640,
#   'date_captured': '2013-11-14 21:54:11',
#   'flickr_url': 'http://farm9.staticflickr.com/8005/7284225450_c38ee955ff_z.jpg',
#   'id': 337264},
#  {'license': 4,
#   'file_name': '000000412151.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000412151.jpg',
#   'height': 334,
#   'width': 500,
#   'date_captured': '2013-11-15 00:04:33',
#   'flickr_url': 'http://farm4.staticflickr.com/3079/3125146921_d0550129e2_z.jpg',
#   'id': 412151},
#  {'license': 6,
#   'file_name': '000000462565.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000462565.jpg',
#   'height': 427,
#   'width': 640,
#   'date_captured': '2013-11-15 01:05:40',
#   'flickr_url': 'http://farm8.staticflickr.com/7396/9146492562_1344ccec28_z.jpg',
#   'id': 462565},
#  {'license': 5,
#   'file_name': '000000173350.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000173350.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-15 01:18:05',
#   'flickr_url': 'http://farm1.staticflickr.com/120/313090696_ea522e2894_z.jpg',
#   'id': 173350},
#  {'license': 1,
#   'file_name': '000000509822.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000509822.jpg',
#   'height': 425,
#   'width': 640,
#   'date_captured': '2013-11-15 02:53:28',
#   'flickr_url': 'http://farm7.staticflickr.com/6095/6220574839_af6b6146b8_z.jpg',
#   'id': 509822},
#  {'license': 6,
#   'file_name': '000000321107.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000321107.jpg',
#   'height': 480,
#   'width': 269,
#   'date_captured': '2013-11-15 03:14:32',
#   'flickr_url': 'http://farm4.staticflickr.com/3038/4555159978_d98b05d459_z.jpg',
#   'id': 321107},
#  {'license': 5,
#   'file_name': '000000232262.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000232262.jpg',
#   'height': 427,
#   'width': 640,
#   'date_captured': '2013-11-15 05:23:22',
#   'flickr_url': 'http://farm9.staticflickr.com/8048/8089005305_a6b2feda80_z.jpg',
#   'id': 232262},
#  {'license': 6,
#   'file_name': '000000565797.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000565797.jpg',
#   'height': 454,
#   'width': 640,
#   'date_captured': '2013-11-15 07:16:08',
#   'flickr_url': 'http://farm7.staticflickr.com/6175/6194686185_723b21149c_z.jpg',
#   'id': 565797},
#  {'license': 6,
#   'file_name': '000000050125.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000050125.jpg',
#   'height': 413,
#   'width': 640,
#   'date_captured': '2013-11-15 10:46:53',
#   'flickr_url': 'http://farm3.staticflickr.com/2100/1544852657_ffccbbc3d1_z.jpg',
#   'id': 50125},
#  {'license': 3,
#   'file_name': '000000394892.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000394892.jpg',
#   'height': 427,
#   'width': 640,
#   'date_captured': '2013-11-15 11:54:07',
#   'flickr_url': 'http://farm8.staticflickr.com/7261/7562949882_01918407aa_z.jpg',
#   'id': 394892},
#  {'license': 3,
#   'file_name': '000000001146.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000001146.jpg',
#   'height': 640,
#   'width': 427,
#   'date_captured': '2013-11-15 11:55:43',
#   'flickr_url': 'http://farm3.staticflickr.com/2145/1861401504_e46f53623a_z.jpg',
#   'id': 1146},
#  {'license': 1,
#   'file_name': '000000463836.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000463836.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-15 12:18:57',
#   'flickr_url': 'http://farm4.staticflickr.com/3292/2733229050_f8c798b46d_z.jpg',
#   'id': 463836},
#  {'license': 1,
#   'file_name': '000000032907.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000032907.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-15 14:08:35',
#   'flickr_url': 'http://farm4.staticflickr.com/3608/3499798248_1381426e82_z.jpg',
#   'id': 32907},
#  {'license': 3,
#   'file_name': '000000268556.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000268556.jpg',
#   'height': 640,
#   'width': 640,
#   'date_captured': '2013-11-15 14:29:00',
#   'flickr_url': 'http://farm3.staticflickr.com/2876/9620553260_a812cd5ca1_z.jpg',
#   'id': 268556},
#  {'license': 6,
#   'file_name': '000000271177.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000271177.jpg',
#   'height': 500,
#   'width': 375,
#   'date_captured': '2013-11-15 14:35:03',
#   'flickr_url': 'http://farm2.staticflickr.com/1337/1360004143_fcf8aaad45_z.jpg',
#   'id': 271177},
#  {'license': 3,
#   'file_name': '000000549399.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000549399.jpg',
#   'height': 424,
#   'width': 640,
#   'date_captured': '2013-11-15 15:02:10',
#   'flickr_url': 'http://farm9.staticflickr.com/8424/7491622748_da89dbcf72_z.jpg',
#   'id': 549399},
#  {'license': 3,
#   'file_name': '000000085160.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000085160.jpg',
#   'height': 425,
#   'width': 640,
#   'date_captured': '2013-11-15 15:14:52',
#   'flickr_url': 'http://farm6.staticflickr.com/5246/5321173112_675e10fb7f_z.jpg',
#   'id': 85160},
#  {'license': 3,
#   'file_name': '000000559665.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000559665.jpg',
#   'height': 397,
#   'width': 640,
#   'date_captured': '2013-11-15 15:25:41',
#   'flickr_url': 'http://farm8.staticflickr.com/7322/9296558150_0fe28321a1_z.jpg',
#   'id': 559665},
#  {'license': 4,
#   'file_name': '000000019358.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000019358.jpg',
#   'height': 426,
#   'width': 640,
#   'date_captured': '2013-11-15 15:40:32',
#   'flickr_url': 'http://farm4.staticflickr.com/3441/3991098638_b029e135a2_z.jpg',
#   'id': 19358},
#  {'license': 4,
#   'file_name': '000000459912.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000459912.jpg',
#   'height': 427,
#   'width': 640,
#   'date_captured': '2013-11-15 15:42:29',
#   'flickr_url': 'http://farm8.staticflickr.com/7391/9081512157_75d5cef187_z.jpg',
#   'id': 459912},
#  {'license': 4,
#   'file_name': '000000394240.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000394240.jpg',
#   'height': 427,
#   'width': 640,
#   'date_captured': '2013-11-15 15:42:40',
#   'flickr_url': 'http://farm6.staticflickr.com/5497/9083616900_0930242ca6_z.jpg',
#   'id': 394240},
#  {'license': 6,
#   'file_name': '000000510755.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000510755.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-15 16:28:39',
#   'flickr_url': 'http://farm6.staticflickr.com/5070/5680563777_16bd981fa7_z.jpg',
#   'id': 510755},
#  {'license': 4,
#   'file_name': '000000074331.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000074331.jpg',
#   'height': 640,
#   'width': 427,
#   'date_captured': '2013-11-15 18:38:36',
#   'flickr_url': 'http://farm6.staticflickr.com/5287/5351312216_04d4d6dcae_z.jpg',
#   'id': 74331},
#  {'license': 4,
#   'file_name': '000000369763.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000369763.jpg',
#   'height': 289,
#   'width': 640,
#   'date_captured': '2013-11-15 19:16:52',
#   'flickr_url': 'http://farm9.staticflickr.com/8177/7897919854_d1dbf69832_z.jpg',
#   'id': 369763},
#  {'license': 6,
#   'file_name': '000000199951.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000199951.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-15 19:22:12',
#   'flickr_url': 'http://farm4.staticflickr.com/3709/9547207842_24eab0e3b2_z.jpg',
#   'id': 199951},
#  {'license': 4,
#   'file_name': '000000452684.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000452684.jpg',
#   'height': 427,
#   'width': 640,
#   'date_captured': '2013-11-15 19:34:46',
#   'flickr_url': 'http://farm6.staticflickr.com/5292/5548702761_16c868feb0_z.jpg',
#   'id': 452684},
#  {'license': 4,
#   'file_name': '000000213687.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000213687.jpg',
#   'height': 479,
#   'width': 640,
#   'date_captured': '2013-11-15 20:04:12',
#   'flickr_url': 'http://farm8.staticflickr.com/7100/7168869419_2b523a5033_z.jpg',
#   'id': 213687},
#  {'license': 4,
#   'file_name': '000000108094.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000108094.jpg',
#   'height': 640,
#   'width': 471,
#   'date_captured': '2013-11-15 20:04:17',
#   'flickr_url': 'http://farm9.staticflickr.com/8006/7360945292_a9df5a0ee4_z.jpg',
#   'id': 108094},
#  {'license': 2,
#   'file_name': '000000527040.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000527040.jpg',
#   'height': 640,
#   'width': 480,
#   'date_captured': '2013-11-15 20:19:37',
#   'flickr_url': 'http://farm2.staticflickr.com/1283/946074610_d181fc83e2_z.jpg',
#   'id': 527040},
#  {'license': 2,
#   'file_name': '000000550529.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000550529.jpg',
#   'height': 612,
#   'width': 612,
#   'date_captured': '2013-11-15 21:14:19',
#   'flickr_url': 'http://farm8.staticflickr.com/7069/6927091799_8e37b8e2ac_z.jpg',
#   'id': 550529},
#  {'license': 1,
#   'file_name': '000000432176.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000432176.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-15 21:53:38',
#   'flickr_url': 'http://farm3.staticflickr.com/2476/3793737301_e0c3ce2f15_z.jpg',
#   'id': 432176},
#  {'license': 2,
#   'file_name': '000000369826.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000369826.jpg',
#   'height': 478,
#   'width': 640,
#   'date_captured': '2013-11-15 23:01:04',
#   'flickr_url': 'http://farm3.staticflickr.com/2859/8929261675_36617ededf_z.jpg',
#   'id': 369826},
#  {'license': 1,
#   'file_name': '000000551334.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000551334.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-15 23:51:36',
#   'flickr_url': 'http://farm1.staticflickr.com/34/121381826_36fc92c7f7_z.jpg',
#   'id': 551334},
#  {'license': 6,
#   'file_name': '000000560623.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000560623.jpg',
#   'height': 360,
#   'width': 640,
#   'date_captured': '2013-11-16 05:55:47',
#   'flickr_url': 'http://farm8.staticflickr.com/7401/9213783677_99cb7b4272_z.jpg',
#   'id': 560623},
#  {'license': 3,
#   'file_name': '000000354533.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000354533.jpg',
#   'height': 310,
#   'width': 640,
#   'date_captured': '2013-11-16 13:58:27',
#   'flickr_url': 'http://farm3.staticflickr.com/2519/4126738647_cc436c111b_z.jpg',
#   'id': 354533},
#  {'license': 2,
#   'file_name': '000000334321.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000334321.jpg',
#   'height': 360,
#   'width': 640,
#   'date_captured': '2013-11-16 15:15:19',
#   'flickr_url': 'http://farm4.staticflickr.com/3198/2816571233_7c043af98c_z.jpg',
#   'id': 334321},
#  {'license': 2,
#   'file_name': '000000484816.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000484816.jpg',
#   'height': 426,
#   'width': 640,
#   'date_captured': '2013-11-16 17:15:22',
#   'flickr_url': 'http://farm3.staticflickr.com/2274/2189624975_aa20ba198a_z.jpg',
#   'id': 484816},
#  {'license': 2,
#   'file_name': '000000165547.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000165547.jpg',
#   'height': 368,
#   'width': 500,
#   'date_captured': '2013-11-16 17:22:11',
#   'flickr_url': 'http://farm2.staticflickr.com/1050/827705229_4f27a557f9_z.jpg',
#   'id': 165547},
#  {'license': 5,
#   'file_name': '000000476005.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000476005.jpg',
#   'height': 428,
#   'width': 640,
#   'date_captured': '2013-11-16 18:19:33',
#   'flickr_url': 'http://farm6.staticflickr.com/5456/8786671291_13d84ed8f0_z.jpg',
#   'id': 476005},
#  {'license': 1,
#   'file_name': '000000067868.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000067868.jpg',
#   'height': 429,
#   'width': 640,
#   'date_captured': '2013-11-16 18:47:39',
#   'flickr_url': 'http://farm9.staticflickr.com/8264/8666095063_a6f8a830b4_z.jpg',
#   'id': 67868},
#  {'license': 3,
#   'file_name': '000000232894.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000232894.jpg',
#   'height': 360,
#   'width': 640,
#   'date_captured': '2013-11-16 19:35:10',
#   'flickr_url': 'http://farm9.staticflickr.com/8297/7870877084_57b312891b_z.jpg',
#   'id': 232894},
#  {'license': 4,
#   'file_name': '000000235302.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000235302.jpg',
#   'height': 425,
#   'width': 640,
#   'date_captured': '2013-11-16 21:15:19',
#   'flickr_url': 'http://farm6.staticflickr.com/5525/9917699333_edd0774dec_z.jpg',
#   'id': 235302},
#  {'license': 1,
#   'file_name': '000000038029.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000038029.jpg',
#   'height': 487,
#   'width': 640,
#   'date_captured': '2013-11-16 22:50:42',
#   'flickr_url': 'http://farm4.staticflickr.com/3616/3691950989_ae68b66e91_z.jpg',
#   'id': 38029},
#  {'license': 3,
#   'file_name': '000000231408.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000231408.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-16 23:12:14',
#   'flickr_url': 'http://farm7.staticflickr.com/6064/6086770677_0b4a005e72_z.jpg',
#   'id': 231408},
#  {'license': 6,
#   'file_name': '000000236182.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000236182.jpg',
#   'height': 640,
#   'width': 480,
#   'date_captured': '2013-11-17 00:10:00',
#   'flickr_url': 'http://farm9.staticflickr.com/8182/8027863897_4328d144d1_z.jpg',
#   'id': 236182},
#  {'license': 6,
#   'file_name': '000000208589.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000208589.jpg',
#   'height': 481,
#   'width': 640,
#   'date_captured': '2013-11-17 00:11:35',
#   'flickr_url': 'http://farm8.staticflickr.com/7053/6813028286_2d1e839017_z.jpg',
#   'id': 208589},
#  {'license': 3,
#   'file_name': '000000334405.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000334405.jpg',
#   'height': 494,
#   'width': 640,
#   'date_captured': '2013-11-17 00:17:59',
#   'flickr_url': 'http://farm9.staticflickr.com/8479/8212475146_43ea4f0216_z.jpg',
#   'id': 334405},
#  {'license': 1,
#   'file_name': '000000073830.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000073830.jpg',
#   'height': 333,
#   'width': 500,
#   'date_captured': '2013-11-17 00:46:53',
#   'flickr_url': 'http://farm4.staticflickr.com/3194/2552519386_e0d6f9049e_z.jpg',
#   'id': 73830},
#  {'license': 3,
#   'file_name': '000000158952.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000158952.jpg',
#   'height': 424,
#   'width': 640,
#   'date_captured': '2013-11-17 00:50:53',
#   'flickr_url': 'http://farm6.staticflickr.com/5312/5883603231_5938893282_z.jpg',
#   'id': 158952},
#  {'license': 4,
#   'file_name': '000000308599.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000308599.jpg',
#   'height': 500,
#   'width': 375,
#   'date_captured': '2013-11-17 00:59:10',
#   'flickr_url': 'http://farm4.staticflickr.com/3119/3242308007_c69afd3a83_z.jpg',
#   'id': 308599},
#  {'license': 6,
#   'file_name': '000000157269.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000157269.jpg',
#   'height': 427,
#   'width': 640,
#   'date_captured': '2013-11-17 01:05:56',
#   'flickr_url': 'http://farm8.staticflickr.com/7416/9414556383_0267859f3b_z.jpg',
#   'id': 157269},
#  {'license': 4,
#   'file_name': '000000327807.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000327807.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-17 05:08:47',
#   'flickr_url': 'http://farm8.staticflickr.com/7091/7350509778_579d936e13_z.jpg',
#   'id': 327807},
#  {'license': 4,
#   'file_name': '000000518586.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000518586.jpg',
#   'height': 492,
#   'width': 640,
#   'date_captured': '2013-11-17 05:20:32',
#   'flickr_url': 'http://farm3.staticflickr.com/2620/3740526563_9b1334a384_z.jpg',
#   'id': 518586},
#  {'license': 3,
#   'file_name': '000000165029.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000165029.jpg',
#   'height': 469,
#   'width': 640,
#   'date_captured': '2013-11-17 05:32:47',
#   'flickr_url': 'http://farm3.staticflickr.com/2682/4078960326_760d498127_z.jpg',
#   'id': 165029},
#  {'license': 3,
#   'file_name': '000000117125.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000117125.jpg',
#   'height': 396,
#   'width': 500,
#   'date_captured': '2013-11-17 05:58:52',
#   'flickr_url': 'http://farm2.staticflickr.com/1141/811936457_a5fd3c5880_z.jpg',
#   'id': 117125},
#  {'license': 1,
#   'file_name': '000000426175.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000426175.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-17 07:16:12',
#   'flickr_url': 'http://farm4.staticflickr.com/3673/9600178068_7a036201fd_z.jpg',
#   'id': 426175},
#  {'license': 4,
#   'file_name': '000000249720.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000249720.jpg',
#   'height': 333,
#   'width': 500,
#   'date_captured': '2013-11-17 08:15:26',
#   'flickr_url': 'http://farm4.staticflickr.com/3587/3630230914_600473b0d3_z.jpg',
#   'id': 249720},
#  {'license': 4,
#   'file_name': '000000329486.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000329486.jpg',
#   'height': 400,
#   'width': 640,
#   'date_captured': '2013-11-17 08:58:41',
#   'flickr_url': 'http://farm4.staticflickr.com/3719/9115013219_344a42ce47_z.jpg',
#   'id': 329486},
#  {'license': 4,
#   'file_name': '000000231163.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000231163.jpg',
#   'height': 400,
#   'width': 640,
#   'date_captured': '2013-11-17 09:18:46',
#   'flickr_url': 'http://farm6.staticflickr.com/5446/9005246493_2a5cb1e620_z.jpg',
#   'id': 231163},
#  {'license': 1,
#   'file_name': '000000463633.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000463633.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-17 09:53:24',
#   'flickr_url': 'http://farm3.staticflickr.com/2103/2147160946_8ed7d30f24_z.jpg',
#   'id': 463633},
#  {'license': 3,
#   'file_name': '000000383470.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000383470.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-17 10:02:25',
#   'flickr_url': 'http://farm1.staticflickr.com/159/407885409_8a2f8a5f43_z.jpg',
#   'id': 383470},
#  {'license': 4,
#   'file_name': '000000578292.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000578292.jpg',
#   'height': 640,
#   'width': 480,
#   'date_captured': '2013-11-17 10:14:07',
#   'flickr_url': 'http://farm6.staticflickr.com/5514/9522314980_552320b6dc_z.jpg',
#   'id': 578292},
#  {'license': 4,
#   'file_name': '000000075748.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000075748.jpg',
#   'height': 400,
#   'width': 640,
#   'date_captured': '2013-11-17 10:14:43',
#   'flickr_url': 'http://farm8.staticflickr.com/7385/8716370241_cd496594a8_z.jpg',
#   'id': 75748},
#  {'license': 6,
#   'file_name': '000000365366.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000365366.jpg',
#   'height': 640,
#   'width': 480,
#   'date_captured': '2013-11-17 10:55:13',
#   'flickr_url': 'http://farm5.staticflickr.com/4100/4742223343_fa5a307d11_z.jpg',
#   'id': 365366},
#  {'license': 2,
#   'file_name': '000000052644.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000052644.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-17 10:58:31',
#   'flickr_url': 'http://farm4.staticflickr.com/3250/2948916040_49787e5c64_z.jpg',
#   'id': 52644},
#  {'license': 3,
#   'file_name': '000000117407.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000117407.jpg',
#   'height': 426,
#   'width': 640,
#   'date_captured': '2013-11-17 15:37:54',
#   'flickr_url': 'http://farm4.staticflickr.com/3635/3309092690_1c2c3e950d_z.jpg',
#   'id': 117407},
#  {'license': 2,
#   'file_name': '000000171500.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000171500.jpg',
#   'height': 426,
#   'width': 640,
#   'date_captured': '2013-11-17 16:15:47',
#   'flickr_url': 'http://farm9.staticflickr.com/8439/7983934560_6265a863b2_z.jpg',
#   'id': 171500},
#  {'license': 3,
#   'file_name': '000000205103.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000205103.jpg',
#   'height': 640,
#   'width': 480,
#   'date_captured': '2013-11-17 17:00:18',
#   'flickr_url': 'http://farm2.staticflickr.com/1334/1214050871_f24e32a9d6_z.jpg',
#   'id': 205103},
#  {'license': 4,
#   'file_name': '000000235006.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000235006.jpg',
#   'height': 443,
#   'width': 640,
#   'date_captured': '2013-11-17 17:06:08',
#   'flickr_url': 'http://farm8.staticflickr.com/7444/9697531142_e287be2470_z.jpg',
#   'id': 235006},
#  {'license': 4,
#   'file_name': '000000182784.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000182784.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-17 17:07:23',
#   'flickr_url': 'http://farm1.staticflickr.com/107/289037878_7f4b1272e9_z.jpg',
#   'id': 182784},
#  {'license': 3,
#   'file_name': '000000319865.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000319865.jpg',
#   'height': 427,
#   'width': 640,
#   'date_captured': '2013-11-17 17:29:52',
#   'flickr_url': 'http://farm1.staticflickr.com/35/97399659_7142e54661_z.jpg',
#   'id': 319865},
#  {'license': 6,
#   'file_name': '000000353968.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000353968.jpg',
#   'height': 333,
#   'width': 500,
#   'date_captured': '2013-11-17 17:44:03',
#   'flickr_url': 'http://farm3.staticflickr.com/2743/4078827657_ebdc92c821_z.jpg',
#   'id': 353968},
#  {'license': 4,
#   'file_name': '000000026942.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000026942.jpg',
#   'height': 383,
#   'width': 640,
#   'date_captured': '2013-11-17 19:16:00',
#   'flickr_url': 'http://farm7.staticflickr.com/6194/6066118824_effb460268_z.jpg',
#   'id': 26942},
#  {'license': 1,
#   'file_name': '000000346207.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000346207.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-17 19:17:14',
#   'flickr_url': 'http://farm5.staticflickr.com/4097/4904764709_03178a7615_z.jpg',
#   'id': 346207},
#  {'license': 3,
#   'file_name': '000000205378.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000205378.jpg',
#   'height': 375,
#   'width': 500,
#   'date_captured': '2013-11-17 21:22:30',
#   'flickr_url': 'http://farm1.staticflickr.com/34/122334984_9876910101_z.jpg',
#   'id': 205378},
#  {'license': 5,
#   'file_name': '000000551952.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000551952.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-17 21:23:24',
#   'flickr_url': 'http://farm8.staticflickr.com/7191/6857412685_2835217e01_z.jpg',
#   'id': 551952},
#  {'license': 1,
#   'file_name': '000000010694.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000010694.jpg',
#   'height': 375,
#   'width': 500,
#   'date_captured': '2013-11-17 21:30:13',
#   'flickr_url': 'http://farm1.staticflickr.com/126/339263720_d41fd69b6b_z.jpg',
#   'id': 10694},
#  {'license': 1,
#   'file_name': '000000181449.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000181449.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-17 21:48:31',
#   'flickr_url': 'http://farm8.staticflickr.com/7091/7277442296_fcc5b2b4e5_z.jpg',
#   'id': 181449},
#  {'license': 3,
#   'file_name': '000000574184.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000574184.jpg',
#   'height': 375,
#   'width': 500,
#   'date_captured': '2013-11-17 21:53:44',
#   'flickr_url': 'http://farm1.staticflickr.com/143/356148801_d6894a20ca_z.jpg',
#   'id': 574184},
#  {'license': 1,
#   'file_name': '000000000400.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000000400.jpg',
#   'height': 640,
#   'width': 638,
#   'date_captured': '2013-11-17 22:13:44',
#   'flickr_url': 'http://farm9.staticflickr.com/8440/7903322692_41e64f3870_z.jpg',
#   'id': 400},
#  {'license': 3,
#   'file_name': '000000232383.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000232383.jpg',
#   'height': 375,
#   'width': 500,
#   'date_captured': '2013-11-18 00:02:50',
#   'flickr_url': 'http://farm1.staticflickr.com/38/122334985_9595296d25_z.jpg',
#   'id': 232383},
#  {'license': 1,
#   'file_name': '000000109819.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000109819.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-18 01:51:00',
#   'flickr_url': 'http://farm7.staticflickr.com/6038/6364870085_cb344ae145_z.jpg',
#   'id': 109819},
#  {'license': 2,
#   'file_name': '000000557981.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000557981.jpg',
#   'height': 640,
#   'width': 428,
#   'date_captured': '2013-11-18 03:21:45',
#   'flickr_url': 'http://farm4.staticflickr.com/3292/3313136103_663f9e96db_z.jpg',
#   'id': 557981},
#  {'license': 1,
#   'file_name': '000000529917.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000529917.jpg',
#   'height': 426,
#   'width': 640,
#   'date_captured': '2013-11-18 04:04:34',
#   'flickr_url': 'http://farm5.staticflickr.com/4014/4720168602_9f0bb71cd9_z.jpg',
#   'id': 529917},
#  {'license': 4,
#   'file_name': '000000410533.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000410533.jpg',
#   'height': 428,
#   'width': 640,
#   'date_captured': '2013-11-18 04:24:29',
#   'flickr_url': 'http://farm5.staticflickr.com/4058/4549672733_9c0f159aa2_z.jpg',
#   'id': 410533},
#  {'license': 4,
#   'file_name': '000000032965.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000032965.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-18 06:17:36',
#   'flickr_url': 'http://farm4.staticflickr.com/3473/3874602774_bfec4f2203_z.jpg',
#   'id': 32965},
#  {'license': 4,
#   'file_name': '000000122934.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000122934.jpg',
#   'height': 424,
#   'width': 640,
#   'date_captured': '2013-11-18 08:53:11',
#   'flickr_url': 'http://farm6.staticflickr.com/5347/7051445863_ac839221a9_z.jpg',
#   'id': 122934},
#  {'license': 3,
#   'file_name': '000000181714.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000181714.jpg',
#   'height': 355,
#   'width': 640,
#   'date_captured': '2013-11-18 09:45:54',
#   'flickr_url': 'http://farm8.staticflickr.com/7264/7443996578_626a0a52f3_z.jpg',
#   'id': 181714},
#  {'license': 1,
#   'file_name': '000000247285.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000247285.jpg',
#   'height': 427,
#   'width': 640,
#   'date_captured': '2013-11-18 10:21:50',
#   'flickr_url': 'http://farm8.staticflickr.com/7019/6579972389_5e6a0bf89e_z.jpg',
#   'id': 247285},
#  {'license': 4,
#   'file_name': '000000042069.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000042069.jpg',
#   'height': 478,
#   'width': 640,
#   'date_captured': '2013-11-18 10:59:21',
#   'flickr_url': 'http://farm7.staticflickr.com/6026/5928810730_189cdd1d29_z.jpg',
#   'id': 42069},
#  {'license': 1,
#   'file_name': '000000139530.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000139530.jpg',
#   'height': 469,
#   'width': 640,
#   'date_captured': '2013-11-18 11:51:31',
#   'flickr_url': 'http://farm6.staticflickr.com/5272/5854283612_9119fa1785_z.jpg',
#   'id': 139530},
#  {'license': 2,
#   'file_name': '000000288955.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000288955.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-18 11:57:40',
#   'flickr_url': 'http://farm4.staticflickr.com/3023/2441079377_e86d4549fc_z.jpg',
#   'id': 288955},
#  {'license': 4,
#   'file_name': '000000103579.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000103579.jpg',
#   'height': 427,
#   'width': 640,
#   'date_captured': '2013-11-18 13:08:02',
#   'flickr_url': 'http://farm2.staticflickr.com/1053/4600250364_9cf4b5261e_z.jpg',
#   'id': 103579},
#  {'license': 1,
#   'file_name': '000000386500.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000386500.jpg',
#   'height': 426,
#   'width': 640,
#   'date_captured': '2013-11-18 13:29:17',
#   'flickr_url': 'http://farm4.staticflickr.com/3085/2903837226_724d07e28f_z.jpg',
#   'id': 386500},
#  {'license': 3,
#   'file_name': '000000370423.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000370423.jpg',
#   'height': 419,
#   'width': 640,
#   'date_captured': '2013-11-18 14:06:34',
#   'flickr_url': 'http://farm3.staticflickr.com/2324/2230539854_10c1a2d8ca_z.jpg',
#   'id': 370423},
#  {'license': 2,
#   'file_name': '000000018149.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000018149.jpg',
#   'height': 360,
#   'width': 640,
#   'date_captured': '2013-11-18 14:35:49',
#   'flickr_url': 'http://farm4.staticflickr.com/3151/2934841984_f6094fc951_z.jpg',
#   'id': 18149},
#  {'license': 1,
#   'file_name': '000000082680.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000082680.jpg',
#   'height': 613,
#   'width': 640,
#   'date_captured': '2013-11-18 16:57:40',
#   'flickr_url': 'http://farm3.staticflickr.com/2772/4237196234_c6ce17ac2e_z.jpg',
#   'id': 82680},
#  {'license': 3,
#   'file_name': '000000469088.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000469088.jpg',
#   'height': 381,
#   'width': 500,
#   'date_captured': '2013-11-18 17:00:32',
#   'flickr_url': 'http://farm4.staticflickr.com/3220/3059776417_d6f3f7acf1_z.jpg',
#   'id': 469088},
#  {'license': 3,
#   'file_name': '000000440329.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000440329.jpg',
#   'height': 427,
#   'width': 640,
#   'date_captured': '2013-11-18 22:31:24',
#   'flickr_url': 'http://farm6.staticflickr.com/5269/5551664633_3d14c0a7b3_z.jpg',
#   'id': 440329},
#  {'license': 4,
#   'file_name': '000000248468.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000248468.jpg',
#   'height': 640,
#   'width': 511,
#   'date_captured': '2013-11-18 22:34:56',
#   'flickr_url': 'http://farm3.staticflickr.com/2429/3730865957_408402aed7_z.jpg',
#   'id': 248468},
#  {'license': 3,
#   'file_name': '000000263136.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000263136.jpg',
#   'height': 437,
#   'width': 640,
#   'date_captured': '2013-11-19 03:33:40',
#   'flickr_url': 'http://farm9.staticflickr.com/8192/8433365521_9252889f9a_z.jpg',
#   'id': 263136},
#  {'license': 4,
#   'file_name': '000000321079.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000321079.jpg',
#   'height': 426,
#   'width': 640,
#   'date_captured': '2013-11-19 18:06:41',
#   'flickr_url': 'http://farm4.staticflickr.com/3505/3965411649_3b175d0820_z.jpg',
#   'id': 321079},
#  {'license': 4,
#   'file_name': '000000147980.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000147980.jpg',
#   'height': 612,
#   'width': 612,
#   'date_captured': '2013-11-19 18:40:50',
#   'flickr_url': 'http://farm4.staticflickr.com/3750/9194479405_3c3e25bbfb_z.jpg',
#   'id': 147980},
#  {'license': 3,
#   'file_name': '000000313789.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000313789.jpg',
#   'height': 376,
#   'width': 500,
#   'date_captured': '2013-11-19 18:48:58',
#   'flickr_url': 'http://farm4.staticflickr.com/3570/3406185666_13c0e11498_z.jpg',
#   'id': 313789},
#  {'license': 2,
#   'file_name': '000000121745.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000121745.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-19 18:49:19',
#   'flickr_url': 'http://farm6.staticflickr.com/5341/9617257920_ef7f8d03ae_z.jpg',
#   'id': 121745},
#  {'license': 3,
#   'file_name': '000000246199.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000246199.jpg',
#   'height': 640,
#   'width': 429,
#   'date_captured': '2013-11-19 19:21:19',
#   'flickr_url': 'http://farm4.staticflickr.com/3129/3248972230_1facb05563_z.jpg',
#   'id': 246199},
#  {'license': 3,
#   'file_name': '000000095427.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000095427.jpg',
#   'height': 500,
#   'width': 500,
#   'date_captured': '2013-11-19 19:27:21',
#   'flickr_url': 'http://farm4.staticflickr.com/3077/3141425741_7d10b54aab_z.jpg',
#   'id': 95427},
#  {'license': 1,
#   'file_name': '000000180800.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000180800.jpg',
#   'height': 612,
#   'width': 612,
#   'date_captured': '2013-11-19 19:43:22',
#   'flickr_url': 'http://farm6.staticflickr.com/5510/9564272944_2ef716236b_z.jpg',
#   'id': 180800},
#  {'license': 1,
#   'file_name': '000000485709.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000485709.jpg',
#   'height': 446,
#   'width': 640,
#   'date_captured': '2013-11-19 19:48:13',
#   'flickr_url': 'http://farm5.staticflickr.com/4055/4588441768_861f9de679_z.jpg',
#   'id': 485709},
#  {'license': 4,
#   'file_name': '000000098590.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000098590.jpg',
#   'height': 478,
#   'width': 640,
#   'date_captured': '2013-11-19 20:03:35',
#   'flickr_url': 'http://farm9.staticflickr.com/8112/8524647037_10336bd44d_z.jpg',
#   'id': 98590},
#  {'license': 5,
#   'file_name': '000000557360.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000557360.jpg',
#   'height': 640,
#   'width': 640,
#   'date_captured': '2013-11-19 20:15:21',
#   'flickr_url': 'http://farm8.staticflickr.com/7272/7592147460_57c15088ab_z.jpg',
#   'id': 557360},
#  {'license': 4,
#   'file_name': '000000034180.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000034180.jpg',
#   'height': 479,
#   'width': 640,
#   'date_captured': '2013-11-19 20:23:08',
#   'flickr_url': 'http://farm8.staticflickr.com/7238/7186899810_6748ac1201_z.jpg',
#   'id': 34180},
#  {'license': 3,
#   'file_name': '000000138975.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000138975.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-19 20:30:14',
#   'flickr_url': 'http://farm9.staticflickr.com/8220/8330885939_b4f4c87253_z.jpg',
#   'id': 138975},
#  {'license': 4,
#   'file_name': '000000570465.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000570465.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-19 20:35:53',
#   'flickr_url': 'http://farm6.staticflickr.com/5249/5357428770_f58c6aceb2_z.jpg',
#   'id': 570465},
#  {'license': 4,
#   'file_name': '000000208663.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000208663.jpg',
#   'height': 334,
#   'width': 500,
#   'date_captured': '2013-11-19 20:41:21',
#   'flickr_url': 'http://farm4.staticflickr.com/3290/3090990005_661d3a6d78_z.jpg',
#   'id': 208663},
#  {'license': 4,
#   'file_name': '000000419856.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000419856.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-19 21:26:34',
#   'flickr_url': 'http://farm3.staticflickr.com/2724/4180618387_45c8b1ca9a_z.jpg',
#   'id': 419856},
#  {'license': 4,
#   'file_name': '000000027353.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000027353.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-19 21:33:07',
#   'flickr_url': 'http://farm3.staticflickr.com/2190/2006174685_ca711ab22d_z.jpg',
#   'id': 27353},
#  {'license': 4,
#   'file_name': '000000210103.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000210103.jpg',
#   'height': 500,
#   'width': 334,
#   'date_captured': '2013-11-19 21:39:12',
#   'flickr_url': 'http://farm3.staticflickr.com/2550/3850220610_0750f2b37f_z.jpg',
#   'id': 210103},
#  {'license': 4,
#   'file_name': '000000362368.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000362368.jpg',
#   'height': 500,
#   'width': 334,
#   'date_captured': '2013-11-19 21:39:15',
#   'flickr_url': 'http://farm3.staticflickr.com/2503/3849426017_68bea65964_z.jpg',
#   'id': 362368},
#  {'license': 4,
#   'file_name': '000000519706.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000519706.jpg',
#   'height': 640,
#   'width': 480,
#   'date_captured': '2013-11-19 21:46:19',
#   'flickr_url': 'http://farm3.staticflickr.com/2575/3693410606_485e41fea7_z.jpg',
#   'id': 519706},
#  {'license': 1,
#   'file_name': '000000472246.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000472246.jpg',
#   'height': 305,
#   'width': 500,
#   'date_captured': '2013-11-19 22:08:01',
#   'flickr_url': 'http://farm3.staticflickr.com/2375/2059804830_3dc6b14319_z.jpg',
#   'id': 472246},
#  {'license': 1,
#   'file_name': '000000420229.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000420229.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-19 22:12:40',
#   'flickr_url': 'http://farm5.staticflickr.com/4090/5090214283_4ed34a154a_z.jpg',
#   'id': 420229},
#  {'license': 5,
#   'file_name': '000000311553.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000311553.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-19 23:02:40',
#   'flickr_url': 'http://farm3.staticflickr.com/2775/4093574378_3d8567135d_z.jpg',
#   'id': 311553},
#  {'license': 1,
#   'file_name': '000000493868.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000493868.jpg',
#   'height': 334,
#   'width': 500,
#   'date_captured': '2013-11-19 23:54:25',
#   'flickr_url': 'http://farm2.staticflickr.com/1031/1224730570_94c2a00721_z.jpg',
#   'id': 493868},
#  {'license': 4,
#   'file_name': '000000296303.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000296303.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-20 00:23:39',
#   'flickr_url': 'http://farm3.staticflickr.com/2728/4105726158_124cd6b3c8_z.jpg',
#   'id': 296303},
#  {'license': 4,
#   'file_name': '000000258516.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000258516.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-20 00:23:44',
#   'flickr_url': 'http://farm3.staticflickr.com/2586/4104960283_3cc8bd827c_z.jpg',
#   'id': 258516},
#  {'license': 3,
#   'file_name': '000000216228.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000216228.jpg',
#   'height': 425,
#   'width': 640,
#   'date_captured': '2013-11-20 01:19:07',
#   'flickr_url': 'http://farm8.staticflickr.com/7037/6839151812_190110363b_z.jpg',
#   'id': 216228},
#  {'license': 1,
#   'file_name': '000000143671.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000143671.jpg',
#   'height': 473,
#   'width': 640,
#   'date_captured': '2013-11-20 03:07:08',
#   'flickr_url': 'http://farm8.staticflickr.com/7281/9740941523_f182ffe8d8_z.jpg',
#   'id': 143671},
#  {'license': 5,
#   'file_name': '000000234572.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000234572.jpg',
#   'height': 426,
#   'width': 640,
#   'date_captured': '2013-11-20 06:00:34',
#   'flickr_url': 'http://farm5.staticflickr.com/4058/4590246461_464f1b89a5_z.jpg',
#   'id': 234572},
#  {'license': 4,
#   'file_name': '000000234500.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000234500.jpg',
#   'height': 427,
#   'width': 640,
#   'date_captured': '2013-11-20 08:50:22',
#   'flickr_url': 'http://farm3.staticflickr.com/2728/5714485519_542a3cbe5e_z.jpg',
#   'id': 234500},
#  {'license': 3,
#   'file_name': '000000262873.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000262873.jpg',
#   'height': 640,
#   'width': 480,
#   'date_captured': '2013-11-20 12:07:58',
#   'flickr_url': 'http://farm2.staticflickr.com/1008/1104142783_12b0ad2adc_z.jpg',
#   'id': 262873},
#  {'license': 1,
#   'file_name': '000000173704.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000173704.jpg',
#   'height': 640,
#   'width': 425,
#   'date_captured': '2013-11-20 12:33:29',
#   'flickr_url': 'http://farm6.staticflickr.com/5166/5367439020_e36d10ca16_z.jpg',
#   'id': 173704},
#  {'license': 1,
#   'file_name': '000000404243.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000404243.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-20 12:35:08',
#   'flickr_url': 'http://farm4.staticflickr.com/3534/3194585403_131cddefc7_z.jpg',
#   'id': 404243},
#  {'license': 5,
#   'file_name': '000000025202.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000025202.jpg',
#   'height': 640,
#   'width': 480,
#   'date_captured': '2013-11-20 13:13:04',
#   'flickr_url': 'http://farm6.staticflickr.com/5210/5208381868_b7bc6a0842_z.jpg',
#   'id': 25202},
#  {'license': 1,
#   'file_name': '000000495107.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000495107.jpg',
#   'height': 640,
#   'width': 480,
#   'date_captured': '2013-11-20 13:32:36',
#   'flickr_url': 'http://farm5.staticflickr.com/4070/4671299015_b459f75463_z.jpg',
#   'id': 495107},
#  {'license': 1,
#   'file_name': '000000399012.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000399012.jpg',
#   'height': 640,
#   'width': 480,
#   'date_captured': '2013-11-20 13:32:41',
#   'flickr_url': 'http://farm5.staticflickr.com/4055/4671919406_7f616d9353_z.jpg',
#   'id': 399012},
#  {'license': 2,
#   'file_name': '000000557780.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000557780.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-20 13:55:25',
#   'flickr_url': 'http://farm3.staticflickr.com/2481/3887513213_ed137b0fcd_z.jpg',
#   'id': 557780},
#  {'license': 4,
#   'file_name': '000000299116.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000299116.jpg',
#   'height': 500,
#   'width': 334,
#   'date_captured': '2013-11-20 14:07:17',
#   'flickr_url': 'http://farm4.staticflickr.com/3340/3187069362_1aabeece97_z.jpg',
#   'id': 299116},
#  {'license': 4,
#   'file_name': '000000569839.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000569839.jpg',
#   'height': 500,
#   'width': 334,
#   'date_captured': '2013-11-20 14:07:20',
#   'flickr_url': 'http://farm4.staticflickr.com/3091/3187069218_162b55b720_z.jpg',
#   'id': 569839},
#  {'license': 2,
#   'file_name': '000000066412.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000066412.jpg',
#   'height': 640,
#   'width': 480,
#   'date_captured': '2013-11-20 14:24:09',
#   'flickr_url': 'http://farm3.staticflickr.com/2168/2232521853_dcc6c989bb_z.jpg',
#   'id': 66412},
#  {'license': 2,
#   'file_name': '000000280819.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000280819.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-20 15:49:40',
#   'flickr_url': 'http://farm3.staticflickr.com/2749/5810413720_9b7ecc7ed1_z.jpg',
#   'id': 280819},
#  {'license': 2,
#   'file_name': '000000427135.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000427135.jpg',
#   'height': 433,
#   'width': 640,
#   'date_captured': '2013-11-20 17:52:19',
#   'flickr_url': 'http://farm3.staticflickr.com/2833/10056050695_d7fd56304e_z.jpg',
#   'id': 427135},
#  {'license': 2,
#   'file_name': '000000201925.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000201925.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-20 18:19:37',
#   'flickr_url': 'http://farm3.staticflickr.com/2454/3989339438_2f32b76ebb_z.jpg',
#   'id': 201925},
#  {'license': 4,
#   'file_name': '000000541010.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000541010.jpg',
#   'height': 427,
#   'width': 640,
#   'date_captured': '2013-11-20 18:52:50',
#   'flickr_url': 'http://farm3.staticflickr.com/2854/9319126920_c63053e8e2_z.jpg',
#   'id': 541010},
#  {'license': 4,
#   'file_name': '000000289444.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000289444.jpg',
#   'height': 427,
#   'width': 640,
#   'date_captured': '2013-11-20 18:52:58',
#   'flickr_url': 'http://farm8.staticflickr.com/7397/9319109332_80d1665d69_z.jpg',
#   'id': 289444},
#  {'license': 2,
#   'file_name': '000000550444.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000550444.jpg',
#   'height': 427,
#   'width': 640,
#   'date_captured': '2013-11-20 20:15:33',
#   'flickr_url': 'http://farm9.staticflickr.com/8365/8462188326_47fbaa800c_z.jpg',
#   'id': 550444},
#  {'license': 3,
#   'file_name': '000000321674.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000321674.jpg',
#   'height': 640,
#   'width': 427,
#   'date_captured': '2013-11-20 20:28:15',
#   'flickr_url': 'http://farm4.staticflickr.com/3665/8759180366_fa0c097b7e_z.jpg',
#   'id': 321674},
#  {'license': 4,
#   'file_name': '000000398076.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000398076.jpg',
#   'height': 427,
#   'width': 640,
#   'date_captured': '2013-11-20 20:30:20',
#   'flickr_url': 'http://farm3.staticflickr.com/2671/4164680879_19e139a8d8_z.jpg',
#   'id': 398076},
#  {'license': 4,
#   'file_name': '000000453926.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000453926.jpg',
#   'height': 426,
#   'width': 640,
#   'date_captured': '2013-11-20 21:27:06',
#   'flickr_url': 'http://farm9.staticflickr.com/8331/8376444197_5bb04780fd_z.jpg',
#   'id': 453926},
#  {'license': 3,
#   'file_name': '000000090935.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000090935.jpg',
#   'height': 427,
#   'width': 640,
#   'date_captured': '2013-11-20 21:32:42',
#   'flickr_url': 'http://farm4.staticflickr.com/3642/3427794390_040af0fb27_z.jpg',
#   'id': 90935},
#  {'license': 3,
#   'file_name': '000000542959.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000542959.jpg',
#   'height': 500,
#   'width': 500,
#   'date_captured': '2013-11-20 21:41:14',
#   'flickr_url': 'http://farm3.staticflickr.com/2004/2476103866_baa22e03f8_z.jpg',
#   'id': 542959},
#  {'license': 4,
#   'file_name': '000000295837.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000295837.jpg',
#   'height': 640,
#   'width': 427,
#   'date_captured': '2013-11-20 22:01:55',
#   'flickr_url': 'http://farm9.staticflickr.com/8189/8137243583_eefc9fd2a1_z.jpg',
#   'id': 295837},
#  {'license': 3,
#   'file_name': '000000207826.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000207826.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-20 22:21:41',
#   'flickr_url': 'http://farm3.staticflickr.com/2065/2243627453_c6474990a3_z.jpg',
#   'id': 207826},
#  {'license': 1,
#   'file_name': '000000385786.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000385786.jpg',
#   'height': 333,
#   'width': 500,
#   'date_captured': '2013-11-20 23:06:49',
# ...
#   'height': 640,
#   'width': 480,
#   'date_captured': '2013-11-24 15:09:27',
#   'flickr_url': 'http://farm5.staticflickr.com/4149/5150702401_74143524cc_z.jpg',
#   'id': 200018},
#  {'license': 3,
#   'file_name': '000000174336.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000174336.jpg',
#   'height': 640,
#   'width': 480,
#   'date_captured': '2013-11-25 08:15:36',
#   'flickr_url': 'http://farm6.staticflickr.com/5336/9618366933_2fc42eca05_z.jpg',
#   'id': 174336},
#  {'license': 1,
#   'file_name': '000000221547.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000221547.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-14 16:32:12',
#   'flickr_url': 'http://farm9.staticflickr.com/8355/8319015928_ff4e6e3bbb_z.jpg',
#   'id': 221547},
#  {'license': 4,
#   'file_name': '000000007256.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000007256.jpg',
#   'height': 346,
#   'width': 640,
#   'date_captured': '2013-11-14 16:40:30',
#   'flickr_url': 'http://farm5.staticflickr.com/4010/5076488785_23a85a0550_z.jpg',
#   'id': 7256},
#  {'license': 1,
#   'file_name': '000000531086.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000531086.jpg',
#   'height': 640,
#   'width': 426,
#   'date_captured': '2013-11-14 16:42:19',
#   'flickr_url': 'http://farm4.staticflickr.com/3522/3932176123_a6db4eb119_z.jpg',
#   'id': 531086},
#  {'license': 1,
#   'file_name': '000000207196.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000207196.jpg',
#   'height': 426,
#   'width': 640,
#   'date_captured': '2013-11-14 17:27:38',
#   'flickr_url': 'http://farm6.staticflickr.com/5485/10036573333_cab4f6e1ea_z.jpg',
#   'id': 207196},
#  {'license': 1,
#   'file_name': '000000436130.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000436130.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-14 18:36:43',
#   'flickr_url': 'http://farm9.staticflickr.com/8137/8746004347_d5f0df0086_z.jpg',
#   'id': 436130},
#  {'license': 3,
#   'file_name': '000000199634.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000199634.jpg',
#   'height': 425,
#   'width': 640,
#   'date_captured': '2013-11-14 20:23:32',
#   'flickr_url': 'http://farm9.staticflickr.com/8190/8118841975_b20b2eb728_z.jpg',
#   'id': 199634},
#  {'license': 1,
#   'file_name': '000000011360.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000011360.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-14 21:59:46',
#   'flickr_url': 'http://farm1.staticflickr.com/203/488288929_0874c7d3d9_z.jpg',
#   'id': 11360},
#  {'license': 4,
#   'file_name': '000000420081.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000420081.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-14 22:52:11',
#   'flickr_url': 'http://farm7.staticflickr.com/6195/6161159178_8fa749a7b7_z.jpg',
#   'id': 420081},
#  {'license': 1,
#   'file_name': '000000148668.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000148668.jpg',
#   'height': 640,
#   'width': 408,
#   'date_captured': '2013-11-14 23:12:58',
#   'flickr_url': 'http://farm4.staticflickr.com/3275/2972752572_29fd4e59a6_z.jpg',
#   'id': 148668},
#  {'license': 3,
#   'file_name': '000000280736.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000280736.jpg',
#   'height': 425,
#   'width': 640,
#   'date_captured': '2013-11-14 23:39:48',
#   'flickr_url': 'http://farm4.staticflickr.com/3503/3810358595_662eeb8e9e_z.jpg',
#   'id': 280736},
#  {'license': 4,
#   'file_name': '000000559312.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000559312.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-15 02:54:15',
#   'flickr_url': 'http://farm8.staticflickr.com/7129/6999945259_fe98a20fe0_z.jpg',
#   'id': 559312},
#  {'license': 3,
#   'file_name': '000000535808.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000535808.jpg',
#   'height': 500,
#   'width': 500,
#   'date_captured': '2013-11-15 03:05:20',
#   'flickr_url': 'http://farm4.staticflickr.com/3634/3592484349_cbc2a8cd6b_z.jpg',
#   'id': 535808},
#  {'license': 1,
#   'file_name': '000000451944.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000451944.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-15 04:35:06',
#   'flickr_url': 'http://farm5.staticflickr.com/4011/4539535025_3e592b998a_z.jpg',
#   'id': 451944},
#  {'license': 2,
#   'file_name': '000000182423.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000182423.jpg',
#   'height': 500,
#   'width': 375,
#   'date_captured': '2013-11-15 05:20:16',
#   'flickr_url': 'http://farm1.staticflickr.com/22/33111079_59d7df2828_z.jpg',
#   'id': 182423},
#  {'license': 3,
#   'file_name': '000000046099.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000046099.jpg',
#   'height': 500,
#   'width': 333,
#   'date_captured': '2013-11-15 05:52:26',
#   'flickr_url': 'http://farm1.staticflickr.com/35/110526772_3fed5c067f_z.jpg',
#   'id': 46099},
#  {'license': 4,
#   'file_name': '000000328091.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000328091.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-15 06:11:59',
#   'flickr_url': 'http://farm5.staticflickr.com/4023/4461002766_d8a738f1aa_z.jpg',
#   'id': 328091},
#  {'license': 3,
#   'file_name': '000000198139.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000198139.jpg',
#   'height': 608,
#   'width': 640,
#   'date_captured': '2013-11-15 06:18:48',
#   'flickr_url': 'http://farm6.staticflickr.com/5146/5559212851_a3cff215f3_z.jpg',
#   'id': 198139},
#  {'license': 1,
#   'file_name': '000000463825.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000463825.jpg',
#   'height': 333,
#   'width': 500,
#   'date_captured': '2013-11-15 06:26:57',
#   'flickr_url': 'http://farm2.staticflickr.com/1234/825261330_4333f1fe34_z.jpg',
#   'id': 463825},
#  {'license': 1,
#   'file_name': '000000435316.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000435316.jpg',
#   'height': 640,
#   'width': 480,
#   'date_captured': '2013-11-15 06:41:57',
#   'flickr_url': 'http://farm1.staticflickr.com/109/255996212_15b5a49d79_z.jpg',
#   'id': 435316},
#  {'license': 1,
#   'file_name': '000000512912.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000512912.jpg',
#   'height': 334,
#   'width': 500,
#   'date_captured': '2013-11-15 13:53:16',
#   'flickr_url': 'http://farm3.staticflickr.com/2655/3762626135_c48298a080_z.jpg',
#   'id': 512912},
#  {'license': 4,
#   'file_name': '000000469134.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000469134.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-15 14:16:12',
#   'flickr_url': 'http://farm4.staticflickr.com/3004/3045400460_0174f9fb0a_z.jpg',
#   'id': 469134},
#  {'license': 3,
#   'file_name': '000000189634.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000189634.jpg',
#   'height': 375,
#   'width': 500,
#   'date_captured': '2013-11-15 15:06:46',
#   'flickr_url': 'http://farm3.staticflickr.com/2176/2531543507_e8282ecb3f_z.jpg',
#   'id': 189634},
#  {'license': 3,
#   'file_name': '000000232488.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000232488.jpg',
#   'height': 640,
#   'width': 639,
#   'date_captured': '2013-11-15 17:28:26',
#   'flickr_url': 'http://farm1.staticflickr.com/203/489169323_41bf0c8216_z.jpg',
#   'id': 232488},
#  {'license': 2,
#   'file_name': '000000059532.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000059532.jpg',
#   'height': 640,
#   'width': 426,
#   'date_captured': '2013-11-15 17:35:57',
#   'flickr_url': 'http://farm5.staticflickr.com/4068/4243518000_2f257f40fb_z.jpg',
#   'id': 59532},
#  {'license': 4,
#   'file_name': '000000208169.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000208169.jpg',
#   'height': 428,
#   'width': 640,
#   'date_captured': '2013-11-15 19:36:51',
#   'flickr_url': 'http://farm9.staticflickr.com/8021/7533510172_b3ac1e2636_z.jpg',
#   'id': 208169},
#  {'license': 3,
#   'file_name': '000000126606.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000126606.jpg',
#   'height': 360,
#   'width': 640,
#   'date_captured': '2013-11-15 20:46:45',
#   'flickr_url': 'http://farm8.staticflickr.com/7138/6971845632_880306819c_z.jpg',
#   'id': 126606},
#  {'license': 4,
#   'file_name': '000000394131.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000394131.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-16 04:40:32',
#   'flickr_url': 'http://farm5.staticflickr.com/4152/5058574242_9a9ecb87b9_z.jpg',
#   'id': 394131},
#  {'license': 5,
#   'file_name': '000000132143.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000132143.jpg',
#   'height': 640,
#   'width': 427,
#   'date_captured': '2013-11-16 12:00:47',
#   'flickr_url': 'http://farm4.staticflickr.com/3129/2646936091_023557540d_z.jpg',
#   'id': 132143},
#  {'license': 2,
#   'file_name': '000000140908.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000140908.jpg',
#   'height': 640,
#   'width': 427,
#   'date_captured': '2013-11-16 12:16:13',
#   'flickr_url': 'http://farm4.staticflickr.com/3208/2538312665_6298a08c5c_z.jpg',
#   'id': 140908},
#  {'license': 5,
#   'file_name': '000000213475.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000213475.jpg',
#   'height': 640,
#   'width': 426,
#   'date_captured': '2013-11-16 12:21:48',
#   'flickr_url': 'http://farm4.staticflickr.com/3274/3005381837_5bf50f935d_z.jpg',
#   'id': 213475},
#  {'license': 4,
#   'file_name': '000000499983.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000499983.jpg',
#   'height': 612,
#   'width': 612,
#   'date_captured': '2013-11-16 12:27:44',
#   'flickr_url': 'http://farm9.staticflickr.com/8337/8171849705_525d86e4dd_z.jpg',
#   'id': 499983},
#  {'license': 5,
#   'file_name': '000000035148.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000035148.jpg',
#   'height': 289,
#   'width': 640,
#   'date_captured': '2013-11-16 13:33:31',
#   'flickr_url': 'http://farm3.staticflickr.com/2391/2237926484_33be543ba4_z.jpg',
#   'id': 35148},
#  {'license': 5,
#   'file_name': '000000493695.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000493695.jpg',
#   'height': 322,
#   'width': 500,
#   'date_captured': '2013-11-16 14:01:37',
#   'flickr_url': 'http://farm3.staticflickr.com/2081/2390362170_e5813321d7_z.jpg',
#   'id': 493695},
#  {'license': 1,
#   'file_name': '000000132578.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000132578.jpg',
#   'height': 358,
#   'width': 500,
#   'date_captured': '2013-11-16 15:05:04',
#   'flickr_url': 'http://farm3.staticflickr.com/2094/2224261576_99542ba851_z.jpg',
#   'id': 132578},
#  {'license': 3,
#   'file_name': '000000328368.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000328368.jpg',
#   'height': 500,
#   'width': 356,
#   'date_captured': '2013-11-16 15:29:51',
#   'flickr_url': 'http://farm1.staticflickr.com/23/26204148_c55467b62a_z.jpg',
#   'id': 328368},
#  {'license': 3,
#   'file_name': '000000477705.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000477705.jpg',
#   'height': 640,
#   'width': 360,
#   'date_captured': '2013-11-16 16:27:41',
#   'flickr_url': 'http://farm5.staticflickr.com/4041/4472930042_7af3867e60_z.jpg',
#   'id': 477705},
#  {'license': 3,
#   'file_name': '000000330754.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000330754.jpg',
#   'height': 500,
#   'width': 375,
#   'date_captured': '2013-11-16 16:45:25',
#   'flickr_url': 'http://farm1.staticflickr.com/109/312297288_1d85860560_z.jpg',
#   'id': 330754},
#  {'license': 6,
#   'file_name': '000000365542.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000365542.jpg',
#   'height': 477,
#   'width': 636,
#   'date_captured': '2013-11-16 17:29:36',
#   'flickr_url': 'http://farm9.staticflickr.com/8512/8555868813_71e7ebd0b6_z.jpg',
#   'id': 365542},
#  {'license': 4,
#   'file_name': '000000436162.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000436162.jpg',
#   'height': 425,
#   'width': 640,
#   'date_captured': '2013-11-16 17:48:05',
#   'flickr_url': 'http://farm6.staticflickr.com/5487/9664058449_9631377044_z.jpg',
#   'id': 436162},
#  {'license': 1,
#   'file_name': '000000156458.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000156458.jpg',
#   'height': 640,
#   'width': 480,
#   'date_captured': '2013-11-16 19:13:06',
#   'flickr_url': 'http://farm9.staticflickr.com/8447/7939858782_4619eacaa6_z.jpg',
#   'id': 156458},
#  {'license': 3,
#   'file_name': '000000287967.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000287967.jpg',
#   'height': 640,
#   'width': 426,
#   'date_captured': '2013-11-16 19:13:39',
#   'flickr_url': 'http://farm4.staticflickr.com/3099/3234183079_3fa5a357cb_z.jpg',
#   'id': 287967},
#  {'license': 2,
#   'file_name': '000000565693.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000565693.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-16 21:56:44',
#   'flickr_url': 'http://farm9.staticflickr.com/8058/8281036169_8fdcc3a74b_z.jpg',
#   'id': 565693},
#  {'license': 1,
#   'file_name': '000000009286.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000009286.jpg',
#   'height': 640,
#   'width': 640,
#   'date_captured': '2013-11-16 21:56:59',
#   'flickr_url': 'http://farm8.staticflickr.com/7285/8804666745_8a71075b0d_z.jpg',
#   'id': 9286},
#  {'license': 2,
#   'file_name': '000000171464.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000171464.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-16 22:10:26',
#   'flickr_url': 'http://farm3.staticflickr.com/2853/8751574702_9d286a7633_z.jpg',
#   'id': 171464},
#  {'license': 2,
#   'file_name': '000000352476.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000352476.jpg',
#   'height': 612,
#   'width': 612,
#   'date_captured': '2013-11-16 22:16:17',
#   'flickr_url': 'http://farm6.staticflickr.com/5339/8761244840_cc3c8abbb3_z.jpg',
#   'id': 352476},
#  {'license': 1,
#   'file_name': '000000321861.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000321861.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-16 23:10:49',
#   'flickr_url': 'http://farm4.staticflickr.com/3322/3606128278_a877854f01_z.jpg',
#   'id': 321861},
#  {'license': 3,
#   'file_name': '000000203257.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000203257.jpg',
#   'height': 427,
#   'width': 640,
#   'date_captured': '2013-11-17 00:11:12',
#   'flickr_url': 'http://farm9.staticflickr.com/8076/8268309430_e36b7d9324_z.jpg',
#   'id': 203257},
#  {'license': 6,
#   'file_name': '000000149123.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000149123.jpg',
#   'height': 478,
#   'width': 640,
#   'date_captured': '2013-11-17 00:11:29',
#   'flickr_url': 'http://farm9.staticflickr.com/8488/8262777056_34008a24ce_z.jpg',
#   'id': 149123},
#  {'license': 1,
#   'file_name': '000000339759.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000339759.jpg',
#   'height': 427,
#   'width': 640,
#   'date_captured': '2013-11-17 00:14:34',
#   'flickr_url': 'http://farm6.staticflickr.com/5005/5270578395_4f165cb1af_z.jpg',
#   'id': 339759},
#  {'license': 3,
#   'file_name': '000000219897.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000219897.jpg',
#   'height': 427,
#   'width': 640,
#   'date_captured': '2013-11-17 00:49:54',
#   'flickr_url': 'http://farm3.staticflickr.com/2721/4294563776_a77c70f70e_z.jpg',
#   'id': 219897},
#  {'license': 1,
#   'file_name': '000000033208.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000033208.jpg',
#   'height': 640,
#   'width': 480,
#   'date_captured': '2013-11-17 03:00:53',
#   'flickr_url': 'http://farm6.staticflickr.com/5044/5326070194_5698b6b44d_z.jpg',
#   'id': 33208},
#  {'license': 1,
#   'file_name': '000000174721.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000174721.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-17 03:43:03',
#   'flickr_url': 'http://farm9.staticflickr.com/8310/7979840563_3373165943_z.jpg',
#   'id': 174721},
#  ...]

# %%
path = '/content/drive/MyDrive/DATASET/'
for img in imgs :
  with open (path+'TrainLabels/'+img['file_name'].split('.')[0]+'.txt', 'w') as f:
    pass

# %%
images = {img['id']: img for img in data['images']}
categories = {cat['id']: idx for idx, cat in enumerate(data['categories'])}

# %%
anns = data['annotations']
for ann in anns :
    image_id = ann['image_id']
    img_info = images[image_id]
    img_w, img_h = img_info['width'], img_info['height']

    # Bounding box
    x_min, y_min, w, h = ann['bbox']
    x_center = (x_min + w / 2) / img_w
    y_center = (y_min + h / 2) / img_h
    w_norm = w / img_w
    h_norm = h / img_h

    class_id = categories[ann['category_id']]

    # YOLO txt file path
    txt_file = path+'TrainLabels/'+img_info['file_name'].split('.')[0]+'.txt'

    # Append annotation to file
    with open(txt_file, 'a') as f:
        f.write(f"{class_id} {x_center:.6f} {y_center:.6f} {w_norm:.6f} {h_norm:.6f}\n")

# %% [markdown]
# # Category Downloading

# %%
classes = {cat['id']: cat['name'] for cat in data['categories']}
with open(path+'Classes/classes.txt', 'w') as f:
    for class_id, class_name in classes.items():
      f.write(f"{class_name}\n")
